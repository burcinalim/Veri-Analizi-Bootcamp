# %% [markdown]
# # Airline Passenger Satisfaction Dataset Analysis

# %% [markdown]
#  A dataset from an airline company's survey related passenger satisfaction was analyzed in this project.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data

# %%
# To upload csv file.
my_data = pd.read_csv('airline_passenger_satisfaction.csv')

#iloc[] was used to ignore first column of the dataset which is an index column.
my_data = my_data.iloc[:, 1:] 

# head() was used to show first five rows.
my_data.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %% [markdown]
# ## Statistical Summary

# %%
## Statistical Summary for numerical variables
my_data.describe()
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000    103904.000000          103904.000000
# mean    64924.210502      39.379706      1189.448375               2.729683
# std     37463.812252      15.114964       997.147281               1.327829
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32533.750000      27.000000       414.000000               2.000000
# 50%     64856.500000      40.000000       843.000000               3.000000
# 75%     97368.250000      51.000000      1743.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# ...

# %%
## Summary table of categorical variables
my_data.describe(include='object')
# Out:
#         Gender   Customer Type   Type of Travel     Class  \
# count   103904          103904           103904    103904
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq     52727           84923            71655     49665
#
#                    satisfaction
# count                    103904
# unique                        2
# top     neutral or dissatisfied
# freq                      58879

# %% [markdown]
# ## Missing Value Analysis

# %% [markdown]
# If there is missing data, it is either deleted (df.dropna()) or filled with mean/median:

# %%
my_data.isnull().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
# Ratio of missing values
(my_data.isnull().sum() / len(my_data)) * 100
# Out:
# id                                   0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.000000
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.000000
# Inflight wifi service                0.000000
# Departure/Arrival time convenient    0.000000
# Ease of Online booking               0.000000
# Gate location                        0.000000
# Food and drink                       0.000000
# Online boarding                      0.000000
# Seat comfort                         0.000000
# Inflight entertainment               0.000000
# On-board service                     0.000000
# Leg room service                     0.000000
# Baggage handling                     0.000000
# Checkin service                      0.000000
# Inflight service                     0.000000
# ...

# %%
# There is 310 missing data in 'Arrival Delay in Minutes' category. So, decided to delete them due to the small proportion of it.
my_data.dropna().head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %% [markdown]
# ## Outlier Analysis

# %% [markdown]
# Data values that are usually statistically extreme are called outliers. We can leave data as is, delete the outliers, review them,and  transform / limit them. We should separate numerical variables from categorical to find outliers because categorical variables don't have statistical significance.

# %%
# Select numerical columns
numeric_df = my_data.select_dtypes(include=['number'])

# Drop unnecessary columns. (We don't need to analyze id column.)
numeric_df = numeric_df.drop(['id'], axis=1)

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(data=numeric_df)
plt.title("Outliers")
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# The above boxplot shows what categories have outliers. Especially **Flight Distance**, **Departure Delay in Minutes**,and **Arrival Delay in Minutes** categories are pointed out. These dimensions may be meaningful for flight reliability. They may not need to be deleted, even if they appear to be contradictory.

# %%
# There is a small variance in Checkin Service dimension in outlier analysis. So, this dimension can be looked at in detail.(According to the boxplot, there is "1 point" which is in the score range, it can be kept within the data. )

sns.boxplot(x=numeric_df['Checkin service'])
plt.title("Checkin Service Outlier Analysis")
plt.show()

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Analysis of Categorical Variables

# %% [markdown]
# #### Gender Distribution

# %%
my_data['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# #### Customer Type Distribution

# %%
my_data['Customer Type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')
plt.title('Customer Type Distribution')
plt.show()

# %% [markdown]
# #### Travel Class Distribution based on Customer Type

# %%
pd.crosstab(my_data['Class'], my_data['Customer Type']).plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# #### Customer Satisfaction Status

# %%
my_data['satisfaction'].value_counts().plot(kind='bar')
plt.title('Customer Satisfaction Status')
plt.show()

# %% [markdown]
# #### Travel Type Distribution

# %%
my_data['Type of Travel'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Travel Type Distribution')
plt.show()

# %% [markdown]
# ### Analysis of Numerical Variables

# %%
# Select just survey's satisfaction dimensions.

survey_dimensions = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking','Gate location','Food and drink','Online boarding','Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service','Cleanliness']

# %% [markdown]
# #### Overall Average Satisfaction Score

# %%
# Create a new column to show avg. satisfaction scores of each customers' evaluation.
my_data['Average_Satisfaction_Score'] = my_data[survey_dimensions].mean(axis=1)

# Calculate overall average score.
overall_avg = my_data['Average_Satisfaction_Score'].mean()
print("Overall Satisfaction Score:", round(overall_avg, 2))
# Out:
# Overall Satisfaction Score: 3.24

# %%
# Visualize average satisfaction score with hisplot.
sns.histplot(my_data['Average_Satisfaction_Score'], bins=20, kde=True)
plt.axvline(overall_avg, color='red', linestyle='--', linewidth=2, label=f'Overall Satisfaction Score: {overall_avg:.2f}')
plt.legend()
plt.title("Distribution of Average Satisfaction Score")
plt.xlabel("Average Score")
plt.ylabel("Customer Count")
plt.show()

# %% [markdown]
# #### Average Satisfaction Scores Chart (Based on Survey Dimensions)

# %%
# Mean scores for each dimension of the survey.

avg_scores_of_dimensions = my_data[survey_dimensions].mean(axis=0)

# %%
mean_scores = avg_scores_of_dimensions.sort_values(ascending=True)
mean_scores.plot(kind='barh', figsize=(10,6), color='skyblue')
plt.title("Average Satisfaction Scores of Dimensions")
plt.xlabel("Average Score")

# to write values of dimensions into the chart
for i, (index, value) in enumerate(mean_scores.items()):
    plt.text(value + 0.05, i, f"{value:.2f}", va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# According to the chart above, 9 out of 14 dimensions are above the overall score(3.24).

# %% [markdown]
# #### Correlation Heatmap (Which Factors Are Similar to Each Other?)

# %% [markdown]
# Correlation shows us how two variables change together. Color intensity indicates the strength of the correlation:
# - Light colors (yellow/orange): High positive correlation
# - Dark colors (blue/red): Negative correlation

# %%
corr_matrix = my_data_selected.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.1f', linewidth='.5')
plt.title("Correlation Heat Map")
plt.show()

# %% [markdown]
# #### Highly Correlated Pairs:(>=0.6)<br>
# - Ease of Online Booking & Inflight Wifi Service : 0.7
# - Cleanliness & Food and Drink: 0.7
# - Cleanliness & Seat Comfort: 0.7
# - Cleanliness & Inflight Entertainment: 0.7
# - Inflight Entertainment & Food and Drink: 0.6
# - Seat Comfort & Food and Drink: 0.6
# - Inflight Entertainment & Seat Comfort: 0.6
# - Inflight Service & On-board Service: 0.6
# - Inflight Service & Baggage Handling: 0.6
#
#
# These high correlations indicate that related services tend to be evaluated together.

# %% [markdown]
# #### Weak or No Correlation:(<=0.2) <br>
#
# - Departure/Arrival time convenient & Inflight wifi service: 0.1
# - Gate location & Seat comfort: 0.0
# - Gate location & Online boarding: 0.0
# - Gate location & Cleanliness: 0.0
# - Leg room service & Many variables (\~0.0 - 0.1)
# - Checkin service & Departure/Arrival time convenient: 0.0
#
# These pairs of variables are evaluated almost independently. So a high level of one does not give information about the other. (all weak pairs were not mentioned above)
